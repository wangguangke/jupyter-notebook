# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
X = np.array([6, 8, 10, 14, 18]).reshape(-1, 1)
# 在scikit-learn中的一个惯用法是将特征向量的矩形命名为X，X表示训练数据的特征
#大写字母表示矩阵，小写字母表示向量

# %%
y = [7, 9, 13, 17.5, 18]

# %%
plt.figure()
plt.title('Pizza price plotted against diameter')
plt.xlabel('Diameter in inches')
plt.ylabel('Price in dollars')
plt.plot(X, y, 'k.')
plt.axis([0, 25, 0, 25])
plt.axis([0, 25, 0, 25])
plt.grid(True)
plt.show()

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
model = LinearRegression() # 创建一个估计器实例
model.fit(X, y)  # 用训练数据拟合模型
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X = np.array([6, 8, 10, 14, 18]).reshape(-1, 1)
y = [7, 9, 13, 17.5, 18]

# %%
test_pizza = np.array([[12]])
predicted_price = model.predict(test_pizza)[0] # predict预测一个解释变量对应的响应变量值
print('A 12" pizza should cost: $%.2f' % predicted_price)
# Out:
# A 12" pizza should cost: $13.68

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.array([6, 8, 10, 14, 18]).reshape(-1, 1)
y = [7, 9, 13, 17.5, 18]
plt.figure()
plt.title('Pizza price plotted against diameter')
plt.xlabel('Diameter in inches')
plt.ylabel('Price in dollars')
plt.plot(X, y, 'ko')
plt.axis([0, 25, 0, 25])
plt.grid(True)
plt.plot([0, 25], [1.97, 26.37], color='k', linestyle='-', linewidth=2)
plt.show()

# %%
plt.figure()
plt.title('Pizza price plotted against diameter')
plt.xlabel('Diameter in inches')
plt.ylabel('Price in dollars')
plt.plot(X, y, 'ko')
plt.axis([0, 25, 0, 25])
plt.grid(True)
plt.plot([0, 25], [0, 28], color='k', linestyle='-', linewidth=2)
plt.plot([0, 25], [1, 29], color='k', linestyle='--', linewidth=2)
plt.plot([-1, 25], [0.5, 27], color='k', linestyle='-.', linewidth=2)
plt.show()

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
X = np.array([6, 8, 10, 14, 18]).reshape(-1, 1)
y = [7, 9, 13, 17.5, 18]

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
test_pizza = np.array([[12]])
predicted_price = model.predict(test_pizza)[0]
print('A 12\" pizza should cost: $%.2f' % predicted_price)
# Out:
# A 12" pizza should cost: $13.68

# %% [markdown]
# 用代价函数评价模型的拟合性
# 代价函数也成为损失函数，它用于定义和衡量一个模型的误差，通常是RSS代价函数

# %%
print('Residual sum of squares: %.2f' % np.mean((model.predict(X) - y) ** 2))
# Out:
# Residual sum of squares: 1.75

# %% [markdown]
# 求解简单线性回归的OLS

# %%
import numpy as np

# %%
X = np.array([[6], [8], [10], [14], [18]]).reshape(-1, 1)
x_bar = X.mean()
print(x_bar)
# Out:
# 11.2

# %%
variance = ((X - x_bar)**2).sum() / (X.shape[0] - 1)
print(variance)
# Out:
# 23.2

# %%
print(np.var(X, ddof=1))
# Out:
# 23.2

# %%
y = np.array([7, 9, 13, 17.5, 18])
y_bar = y.mean()
covariance = np.multiply((X - x_bar).transpose(), y - y_bar).sum() / (X.shape[0] - 1)
print(covariance)
print(np.cov(X.transpose(), y)[0][1])
# Out:
# 22.65
# 22.650000000000002

# %%
import numpy as np

# %%
from sklearn.linear_model import LinearRegression

# %%
X = np.array([6, 8, 10, 14, 18]).reshape(-1, 1)
y = [7, 9, 13, 17.5, 18]

# %%
X_train = np.array([6, 8, 10, 14, 18]).reshape(-1, 1)
y_train = [7, 9, 13, 17.5, 18]

# %%
X_test = np.array([8, 9, 11, 16, 12]).reshape(-1, 1)
y_test = [11, 8.5, 15, 18, 11]

# %%
model = LinearRegression()
model.fit(X_train, y_train)
r_squared = model.score(X_test, y_test)
print(r_squared)
# Out:
# 0.6620052929422553
